# %% [markdown]
# ### extract bibliographies

# %%
import sys
sys.path.append('biblib')

# %%
import biblib.bib
import biblib.algo
file_name = 'NuyujukianRefs.bib'
test_file = 'test-bibs/coleman_test.bib'
test_file = 'test-bibs/multiple_first_authors_test.bib'
f = open(file_name, "r")
# f = open(test_file, "r")

# %%
db = biblib.bib.Parser(month_style='mine').parse(f, log_fp=sys.stderr).get_entries()
db = biblib.bib.resolve_crossrefs(db)
# Out:
# MONTH STYLE mine

# %%
def get_first_and_rest_authors(authors):
    authors_list = biblib.algo.parse_names(authors)
    n = len(authors_list)
    if n == 0:
        raise Exception("ZERO AUTHORS")
    # add first authors
    first = [authors_list[0]]
    if n - len(first) > 0:
        for i in range(1, n):
            if '*' not in authors_list[i].first:
                break
            first.append(authors_list[i])

    rest = []
    if n - len(first) > 0:
        rest = authors_list[1:]
    clean_first = [name.last for name in first]
    clean_rest = [name.last for name in rest]
    return clean_first, clean_rest

# %%
def get_pdf_name(ent, print_vals=False):
    if 'title' not in ent:
        raise Exception("NO TITLE FOUND")
    url = ''
    if 'bdsk-url-1' in ent:
        url = ent['bdsk-url-1']
    else:
        url = ent['title']
    if 'author' not in ent:
        print("NO AUTHOR FOUND")
        return ent.key, url
    if 'year' not in ent:
        raise Exception("NO YEAR FOUND")
    # get authors
    first, rest = get_first_and_rest_authors(ent['author'])
    num_first = len(first)
    num_rest = len(rest)
    # get journal
    title_wo_date = ent.key[:-4]
    for name in first + rest:
        title_wo_date = title_wo_date.replace(name, '', 1)
    title_wo_EtAl = title_wo_date.replace('EtAl', '', 1)
    title_wo_ElAl = title_wo_EtAl.replace('ElAl', '', 1)
    journal = title_wo_ElAl.replace('Etl', '', 1)
    year = ent['year']

    # build file names
    title = ''
    if num_first + num_rest <= 2:
        # If there are two or less authors, list all authors and drop the et al.
        title += ''.join(first) + ''.join(rest)
        title += journal + year
    elif num_first == 2:
        # If there are two co-first authors, list both before the et al.
        title += ''.join(first)
        title += 'EtAl' + journal + year
    elif num_first > 2:
        # If there are more than two co-first authors, just list the first author.
        title += first[0] + 'EtAl' + journal + year
    else:
        # If there is one first authors, just list the first author.
        title += first[0] + 'EtAl' + journal + year
    return title, url

# %%
def debug_db(db):
    count = 0
    db.values()
    for ent in db.values():
        pdf_name = get_pdf_name(ent)[0]
        if pdf_name != ent.key:
            print('{ent.key} ({ent.typ}):'.format(ent=ent))
            print(get_pdf_name(ent))
            print()
            count+=1
    len(db.values())

# %%
debug_db(db)
# Out:
# ZijlmansElAlNatRevNeurol2019 (article):
# ('ZijlmansEtAlNatRevNeurol2019', 'https://doi.org/10.1038/s41582-019-0224-y')
#
# SalomonLancet2012 (article):
# ('SalomonEtAlLancet2012', 'http://www.ncbi.nlm.nih.gov/pubmed/23245605')
#
# TatumClinNeurophys2018 (article):
# ('TatumEtAlClinNeurophys2018', 'http://www.ncbi.nlm.nih.gov/pubmed/29483017')
#
# NO AUTHOR FOUND
# NO AUTHOR FOUND
# BurstenElecClinNeuro1957 (article):
# ('BURSTENBurstenElecClinNeuro1957', 'https://doi.org/10.1016/0013-4694(57)90043-3')
#
# VesunaKauvarEtAlNature2020 (article):
# ('VesunaEtAlNature2020', 'https://doi.org/10.1038/s41586-020-2731-9')
#
# MehrotraDasguptaEtAlLCTES2018 (inproceedings):
# ('MehrotraEtAlLCTES2018', 'https://doi.org/10.1145/3211332.3211344')
#
# NO AUTHOR FOUND
# NO AUTHOR FOUND
# NO AUTHOR FOUND
# NO AUTHOR FOUND
# NO AUTHOR FOUND
# SternsonEtAlAnnRevNeuro2014 (article):
# ('SternsonRothAnnRevNeuro2014', 'http://dx.doi.org/10.1146/annurev-neuro-071013-014048')
#
# BaniAhmedThesis2013 (jurthesis):
# ('Bani-AhmedBaniAhmedThesis2013', 'https://kuscholarworks.ku.edu/bitstream/handle/1808/14207/BANIAHMED_ku_0099D_12951_DATA_1.pdf?sequence=1')
#
# TaubNatureRevNeurosci2002 (article):
# ('TaubEtAlNatureRevNeurosci2002', 'http://dx.doi.org/10.1038/nrn754')
#
# SacuedaSchmidtLabAnimal2000 (article):
# ('SacedaSchmidtSacuedaLabAnimal2000', 'Refining macaque handling and restraint techniques')
#
# NO AUTHOR FOUND
# DeathFactSheet2017WHO (article):
# ('OrganizationDeathFactSheet2012017', 'The top 10 causes of death in 2015')
#
# NO AUTHOR FOUND
# FetzEtAlScience1969 (article):
# ('FetzScience1969', 'Operant conditioning of cortical unit activity.')
#
# FetzEtAlBehavioralBrainSciences1992 (article):
# ('FetzBehavioralBrainSciences1992', 'Are movement parameters recognizably coded in the activity of single neurons')
#
# HumphreySchmidtThompsonScience1970 (article):
# ('HumphreyEtAlScience1970', 'Predicting measures of motor performance from multiple cortical spike trains.')
#
# FriedOkenEtAlNeuroRehab2015 (article):
# ('Fried-OkenEtAlFriedOkenNeuroRehab2015', 'http://dx.doi.org/10.3233/NRE-151241')
#
# NO AUTHOR FOUND
# PandarinathEtAlSFN2014 (inproceedings):
# ('PandarinathNuyujukianEtAlSFN2014', 'Application of a high performance intracortical brain computer interface for communication in a person with amyotrophic lateral sclerosis')
#
# NuyujukianEtAlSFN2014 (inproceedings):
# ('NuyujukianPandarinathEtAlSFN2014', 'Design of a high performance intracortical brain computer interface for a person with amyotrophic lateral sclerosis')
#
# ChhatbarFrancesPLoSOne2013 (article):
# ('ChhatbarFrancisFrancesPLoSOne2013', 'http://dx.doi.org/10.1371/journal.pone.0052286')
#
# NewmanSproullPICG1979Radial (inbook):
# ('NewmanSproullPICG1979Ra1979', 'Principles of Interactive Computer Graphics')
#
# VolosyakEtAlJNE2011 (article):
# ('VolosyakJNE2011', 'http://dx.doi.org/10.1088/1741-2560/8/3/036020')
#
# HarrisonEtAlJSSC2003 (article):
# ('HarrisonCharlesJSSC2003', 'http://dx.doi.org/10.1109/JSSC.2003.811979')
#
# SerruyaBioCyb2003 (article):
# ('SerruyaEtAlBioCyb2003', 'http://dx.doi.org/10.1007/s00422-002-0374-6')
#
# DickeyJNeurophys2009 (article):
# ('DickeyEtAlJNeurophys2009', 'http://jn.physiology.org/content/102/2/1331.abstract')
#
# SunerTNSRE2005 (article):
# ('SunerEtAlTNSRE2005', 'http://dx.doi.org/10.1109/TNSRE.2005.857687')
#
# GolubEMBC2012 (inproceedings):
# ('GolubEtAlEMBC2012', '{Internal Models Engaged by Brain-computer Interface Control}')
#
# McFarlandJNE2010 (article):
# ('McFarlandEtAlJNE2010', 'Electroencephalographic (EEG) control of three-dimensional movement')
#
# SchalkJNE2008 (article):
# ('SchalkEtAlJNE2008', 'Two-dimensional movement control using electrocorticographic signals in humans')
#
# LiNeuralComp2011 (article):
# ('LiEtAlNeuralComp2011', 'Adaptive Decoding for Brain-Machine Interfaces Through Bayesian Parameter Updates')
#
# KollerProbabilisticGraphicalModels2009 (book):
# ('KollerFriedmanProbabilisticGraphicalModels2009', 'Probabilistic Graphical Models')
#
# OrtegaBayesianControl2010 (article):
# ('OrtegaBraunBayesianControl2010', 'A Bayesian rule for adaptive control based on causal interventions')
#
# GageJNE2005 (article):
# ('GageEtAlJNE2005', 'Naive coadaptive cortical control')
#
# TkachCONB2008 (article):
# ('TkachEtAlCONB2008', 'http://dx.doi.org/10.1016/j.conb.2008.09.016')
#
# WahnounJNeurosci2006 (article):
# ('WahnounEtAlJNeurosci2006', 'http://stacks.iop.org/1741-2552/3/i=2/a=010')
#
# SanchezTBME2004 (article):
# ('SanchezEtAlTBME2004', 'http://www.ncbi.nlm.nih.gov/pubmed/15188862')
#
# MacKenzieSIGCHI1992 (inproceedings):
# ('MacKenzieBuxtonSIGCHI1992', "Extending Fitts' law to two-dimensional tasks")
#
# CardErgonomics1978 (article):
# ('CardEtAlErgonomics1978', 'http://dx.doi.org/10.1080/00140137808931762')
#
# ZhaiHCI2002 (article):
# ('ZhaiEtAlHCI2002', 'http://www.tandfonline.com/doi/abs/10.1080/07370024.2002.9667315')
#
# SchalkandLeuthardtIEEERBME2011 (article):
# ('SchalkLeuthardtandIEEERBME2011', 'http://dx.doi.org/10.1109/RBME.2011.2172408')
#
# ODohertyEtAlNature2011 (article):
# ("O'DohertyEtAlODohertyNature2011", 'http://dx.doi.org/10.1038/nature10489')
#
# NuyujukianCOSYNE2012 (inproceedings):
# ('NuyujukianEtAlCOSYNE2012', 'A high-performance robust brain-machine interface without retraining')
#
# NicolasAlonsoSensors2012 (article):
# ('Nicolas-AlonsoGomez-GilNicolasAlonsoSensors2012', 'http://www.mdpi.com/1424-8220/12/2/1211')
#
# KrusienskiEtAlJNeurosciMethods2008 (article):
# ('KrusienskiEtAlJNeurosciethods2008', 'http://www.sciencedirect.com/science/article/pii/S0165027007003706')
#
# KoralekNat2012 (article):
# ('KoralekEtAlNat2012', 'http://dx.doi.org/10.1038/nature10845')
#
# FlintEMBC2012 (inproceedings):
# ('FlintEtAlEMBC2012', 'Control of a Biomimetic Brain Machine Interface with Local Field Potentials: Performance and Stability of a Static Decoder Over 200 Days')
#
# BlankertzIEEETNSRE2003 (article):
# ('BlankertzEtAlIEEETNSRE2003', 'http://dx.doi.org/10.1109/TNSRE.2003.814456')
#
# GiljaEMBC2012 (inproceedings):
# ('GiljaEtAlEMBC2012', 'A Brain Machine Interface Control Algorithm Designed from a Feedback Control Perspective')
#
# ShpigelmanNIPS2009 (article):
# ('ShpigelmanEtAlNIPS2009', 'Kernel-arma for hand tracking and brain-machine interfacing during 3D motor control.')
#
# GiljaSFN2010 (article):
# ('GiljaEtAlSFN2010', 'A high-performance continuous cortically-controlled prosthesis enabled by feedback control design.')
#
# DiesterNatNeuro2011 (article):
# ('DiesterEtAlNatNeuro2011', 'An optogenetic toolbox designed for primates')
#
# HanNeuron2009 (article):
# ('HanEtAlNeuron2009', 'http://dx.doi.org/10.1016/j.neuron.2009.03.011')
#
# SadtlerNER2011 (article):
# ('SadtlerEtAlNER2011', 'High-performance neural prosthetic control along instructed paths')
#
# Vargas-IrwinJNeurosci2010 (article):
# ('Vargas-IrwinEtAlJNeurosci2010', 'http://dx.doi.org/10.1523/JNEUROSCI.5443-09.2010')
#
# GangulyJNeurosci2009 (article):
# ('GangulyEtAlJNeurosci2009', 'http://dx.doi.org/10.1523/JNEUROSCI.2471-09.2009')
#
# CerebCortex2009 (article):
# ('Touzalin-ChretienEtAlCerebCortex2009', 'Dominance of Vision over Proprioception on Motor Programming: Evidence from ERP')
#
# ShadmehrJNeurosci1994 (article):
# ('ShadmehrMussa-IvaldiJNeurosci1994', '{Adaptive representation of dynamics during learning of a motor task}')
#
# HowardJNeurosciMethods2009 (article):
# ('HowardEtAlJNeurosciMethods2009', 'A modular planar robotic manipulandum with end-point torque control')
#
# SoberJNeurosci2003 (article):
# ('SoberSabesJNeurosci2003', '{Multisensory Integration during Motor Planning}')
#
# VanBeersJNeurophys1999 (article):
# ('VanBeersEtAlJNeurophys1999', 'Integration of Proprioceptive and Visual Position-Information: An Experimentally Supported Model')
#
# FranklinJNeurosci2008 (article):
# ('FranklinWolpertJNeurosci2008', 'Specificity of Reflex Adaptation for Task-Relevant Variability')
#
# TianEMBC2003 (inproceedings):
# ('TianHeEMBC2003', 'Can {EMG} machine interface be used to model brain machine interface?')
#
# SantucciEurJNeurosci2005 (article):
# ('SantucciEtAlEurJNeurosci2005', 'Frontal and parietal cortical ensembles predict single-trial muscle activity during reaching movements in primates.')
#
# WolpertNatNeuro2000 (article):
# ('WolpertGhahramaniNatNeuro2000', 'Computational Principles of Movement Neuroscience')
#
# GhahramaniNat1997 (article):
# ('GhahramaniWolpertNat1997', 'Modular Decomposition in Visuoumotor Learning')
#
# ShadmehrNeurobioPointReach2005 (book):
# ('ShadmehrWiseNeurobioPointReach2005', 'The Computational Neurobiology of Pointing and Reaching')
#
# KumarSIGCHI2007 (article):
# ('KumarEtAlSIGCHI2007', 'EyePoint: Practical pointing and selection using gaze and keyboard')
#
# JellinekSIGCHI1990 (article):
# ('JellinekCardSIGCHI1990', 'Powermice and user performance')
#
# WinogradUsability1992 (book):
# ('AdlerWinogradUsability1992', 'Usability: Turning Technologies into Tools')
#
# WinogradCompCog1987 (book):
# ('WinogradFloresCompCog1987', 'Understanding Computers and Cognition: A new foundation for design')
#
# ACM1999 (incollection):
# ('DouglasEtAlACM1999', 'Testing pointing device performance and user assessment with the ISO9241, Part 9 standard')
#
# WuSAB2002 (inproceedings):
# ('WuEtAlSAB2002', 'Inferring hand motion from multi-cell recordings in motor cortex using a {K}alman filter')
#
# ChurchlandNeuron2010 (article):
# ('ChurchlandEtAlNeuron2010', 'Cortical preparatory activity: Representation of movement or first cog in a dynamical machine?')
#
# DayanTheoreticalNeuro2001 (book):
# ('DayanAbbottTheoreticalNeuro2001', 'Theoretical Neuroscience')
#
# ChurchlandShenoyJNeurophys2007b (article):
# ('ChurchlandShenoyJNeurophys22007', 'Temporal complexity and heterogeneity of single-neuron activity in premotor and motor cortex')
#
# ChurchlandShenoyJNeurophys2007a (article):
# ('ChurchlandShenoyJNeurophys22007', 'Delay of movement caused by disruption of cortical preparatory activity')
#
# MoranJNeurophys1999 (article):
# ('MoranSchwartzJNeurophys1999', 'Motor cortical representation of speed and direction during reaching')
#
# CunninghamNeuralNet2009 (article):
# ('CunninghamEtAlNeuralNet2009', 'Methods for estimating neural firing rates, and their application to brain-machine interfaces')
#
# CunninghamJNeurophys2008 (article):
# ('CunninghamEtAlJNeurophys2008', 'Toward Optimal Target Placement for Neural Prosthetic Devices')
#
# TodorovNatNeuro2002 (article):
# ('TodorovJordanNatNeuro2002', 'Optimal Feedback Control as a Theory of Motor Coordination')
#
# HerzfeldJNE2010 (article):
# ('HerzfeldBeardsleyJNE2010', 'Improved multi-unit decoding at the brain-machine interface using population temporal linear filtering')
#
# SanthanamEMBC2004 (inproceedings):
# ('SanthanamEtAlEMBC2004', 'An extensible infrastructure for fully automated spike sorting during online experiments')
#
# GiljaCOSYNE2010 (article):
# ('GiljaEtAlCOSYNE2010', 'High-performance continuous neural control enabled by a feedback control perspective')
#
# TaylorEtAlSFN2009 (article):
# ('MaratheEtAlSFN2009', 'Are your movement decoding methods appropriate for online control of neuroprosthetics?')
#
# DanzigerTBME2009 (article):
# ('DanzigerEtAlTBME2009', 'Learning Algorithms for Human-Machine Interfaces')
#
# RadhakrishnanJNeurophys2008 (article):
# ('RadhakrishnanEtAlJNeurophys2008', '{Learning a Novel Myoelectric-Controlled Interface Task}')
#
# KoyamaJCompNeurosci2009 (article):
# ('KoyamaEtAlJCompNeurosci2009', 'Comparison of brain-computer interface decoding algorithms in open-loop and closed-loop control')
#
# ChaseNeuralNet2009 (article):
# ('ChaseEtAlNeuralNet2009', 'Bias, optimal linear estimation, and the differences between open-loop simulation and closed-loop performance of spiking-based brain-computer interface algorithms')
#
# SanchezIEEESigProcMag2008 (article):
# ('SanchezEtAlIEEESigProcMag2008', 'Technology and Signal Processing for Brain-Machine Interfaces: The need for beyond the state-of-the-art tools')
#
# KulkarniIEEESigProcMag2008 (article):
# ('KulkarniPaninskiIEEESigProcMag2008', 'State-space decoding of goal-directed movements')
#
# MoritzNat2008 (article):
# ('MoritzEtAlNat2008', 'Direct control of paralysed muscles by cortical neurons')
#
# WuIEEEBRB2008 (inproceedings):
# ('WuHatsopoulosIEEEBRB2008', 'Target-included model and hybrid decoding of stereotyped hand movement in the motor cortex')
#
# MullikenJNeurosci2008 (article):
# ('MullikenEtAlJNeurosci2008', 'Decoding trajectories from posterior parietal cortex ensembles')
#
# ArtemiadisEMBC2007 (inproceedings):
# ('ArtemiadisEtAlEMBC2007', 'Decoding Grasp Aperture from Motor-Cortical Population Activity')
#
# SrinivasanJNeurophys2007 (article):
# ('SrinivasanEtAlJNeurophys2007', 'General Purpose Filter Design for Neural Prosthetic Systems')
#
# YuJNeurophys2007 (article):
# ('YuEtAlJNeurophys2007', 'Mixture of Trajectory Models for Neural Decoding of Goal-Directed Movements')
#
# SrinivasanTBME2007 (article):
# ('SrinivasanBrownTBME2007', 'A State-Space Framework for Movement Control to Dynamic Goals Through Brain-Driven Interfaces')
#
# SrinivasanNeuralComp2006 (article):
# ('SrinivasanEtAlNeuralComp2006', 'A State-Space Analysis for Reconstruction of goal-directed movements using neural signals')
#
# ShakhnarovichNIPS2006 (incollection):
# ('ShakhnarovichEtAlNIPS2006', 'Nonlinear physically-based models for decoding motor-cortical population activity')
#
# KimJNE2006 (article):
# ('KimEtAlJNE2006', 'A comparison of optimal MIMO linear and nonlinear models for brain-machine interfaces')
#
# ShohamTBME2005 (article):
# ('ShohamEtAlTBME2005', 'Statistical encoding model for a primary motor cortical brain-machine interface')
#
# PaninskiJNeurosci2004 (article):
# ('PaninskiEtAlJNeurosci2004', 'Superlinear population encoding of dynamic hand trajectory in primary motor cortex')
#
# BrockwellJNeurophys2004 (article):
# ('BrockwellEtAlJNeurophys2004', 'Recursive Bayesian Decoding of Motor Cortical Signals by Particle Filtering')
#
# KemereTBME2004 (article):
# ('KemereEtAlTBME2004', 'Model-based neural decoding of reaching movements: a maximum likelihood approach')
#
# EdenNeuralComp2004 (article):
# ('EdenEtAlNeuralComp2004', 'Dynamic Analysis of Neural Encoding by Point Process Adaptive Filtering')
#
# GaoNIPS2002 (article):
# ('GaoEtAlNIPS2002', 'Probabilistic Inference of Hand Motion from Neural Activity in Motor Cortex')
#
# BrownJNeurosci1998 (article):
# ('BrownEtAlJNeurosci1998', 'A Statistical Paradigm for Neural Spike Train Decoding Applied to Position Prediction from the Ensemble Firing Patterns of Rat Hippocampal Place Cells')
#
# ChestekJEtAlNeurosci2007 (article):
# ('ChestekEtAlJNeurosci2007', 'Single-neuron stability during repeated reaching in macaque premotor cortex')
#
# WuNeuralComp2006 (article):
# ('WuEtAlNeuralComp2006', 'Bayesian population decoding of motor cortical activity using a {K}alman filter')
#
# LebedevJNeurosci2005 (article):
# ('LebedevEtAlJNeurosci2005', 'Cortical Ensemble Adaptation to Represent Velocity of an Artificial Actuator Controlled by a Brain-Machine Interface')
#
# HatsopoulosJNeurophys2004 (article):
# ('HatsopoulosEtAlJNeurophys2004', 'Decoding continuous and discrete motor behaviors using motor and premotor cortical ensembles')
#
# WuTBME2004 (article):
# ('WuEtAlTBME2004', 'Modeling and Decoding Motor Cortical Activity using a Switching {K}alman Filter')
#
# ShenoyNeuroReport2003 (article):
# ('ShenoyEtAlNeuroReport2003', 'Neural prosthetic control signals from plan activity')
#
# GeorgopoulosScience1986 (article):
# ('GeorgopoulosEtAlScience1986', 'Neuronal population coding of movement direction')
#
# LebedevTN2006 (article):
# ('LebedevNicolelisTN2006', 'Brain-machine interfaces: past, present, and future')

# %%
pdf_names = [get_pdf_name(ent) for ent in db.values()]
# Out:
# NO AUTHOR FOUND
# NO AUTHOR FOUND
# NO AUTHOR FOUND
# NO AUTHOR FOUND
# NO AUTHOR FOUND
# NO AUTHOR FOUND
# NO AUTHOR FOUND
# NO AUTHOR FOUND
# NO AUTHOR FOUND
# NO AUTHOR FOUND

# %%
pdf_names_w_doi_link = []
doi_links = []

pdf_names_w_link = []
other_links = []

pdf_names_wo_link = []

for pdf_name, url in pdf_names:
    
    if 'doi' in url:
        pdf_names_w_doi_link.append('{},{}\n'.format(pdf_name, url))
        # pdf_names_w_doi_link.append(pdf_name + '\n')
        # doi_links.append(url + '\n')
    elif 'https' in url or 'http' in url:
        pdf_names_w_link.append(pdf_name + '\n')
        other_links.append(url + '\n')
    else:
        pdf_names_wo_link.append('{},{}\n'.format(pdf_name, url))
assert((len(pdf_names_w_doi_link) + len(pdf_names_w_link) + len(pdf_names_wo_link)) == len(pdf_names))

# %%
len(pdf_names_w_doi_link), len(pdf_names_w_link), len(pdf_names_wo_link)
# Out:
# (260, 20, 180)

# %%
test_output = 'test-output/'
pdf_names_w_doi_link_file = open(test_output + 'pdf_names_w_doi_link.txt', "w")
pdf_names_w_doi_link_file.writelines(pdf_names_w_doi_link)
doi_links_file = open(test_output + 'doi_links.txt', "w")
doi_links_file.writelines(doi_links)

pdf_names_w_link_file = open(test_output + 'pdf_names_w_link.txt', "w")
pdf_names_w_link_file.writelines(pdf_names_w_link)
other_links_file = open(test_output + 'other_links.txt', "w")
other_links_file.writelines(other_links)

pdf_names_wo_link_file = open(test_output + 'pdf_names_wo_link.txt', "w")
pdf_names_wo_link_file.writelines(pdf_names_wo_link)

# %%
len(pdf_names_w_doi_link)
# Out:
# 260
